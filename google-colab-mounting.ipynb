# %% [markdown]
# # Google Colab Mounting Walkthrough
#
# Steps to get project running on google colab
#
# * We'll need to mount the drive to get a working terminal

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# * After this step is done we need to move our environment into the correct directory. This directory path should match the location of the repo in the drive. It will be different per user.
#   * In this example, the repository is relative to my shortcut, you should replace this string with your relative path:
#     * `drive/MyDrive/DS4A/DS4A\ Team\ 109/data-cleaning`

# %%
# %cd drive/MyDrive/DS4A/DS4A\ Team\ 109/data-cleaning

# %% [markdown]
# * If you run `git status` you should see the repository's status, you should be able to see the repository's contents
#   * If you are lost, run `!pwd` and `ls` to find the correct path

# %%
# !pwd
# !ls -a

# %% [markdown]
# ## Saving to github
#
# Make sure you keep this notebook open to maintain the current working directory.
#
# After making changes to the files and reaching a point where you'd like to save the current state, you need to make sure you run the following git configurations to ensure proper git flow.

# %% [markdown]
# ### Github Workflow
#
# * Set the following configs where:
#   * `email@domain.ex` is the primary email in your github account
#   * `Funky User` is the name you use in your github account

# %%
# !git config --global user.email "email@domain.ex"
# !git config --global user.name "Funky User"

# %% [markdown]
# * You can now run
#   * `git add <files>`
#   * `git commit -m "<message>"`
#   * `git push origin main`
#
# * This should complete the git workflow when saving changes
