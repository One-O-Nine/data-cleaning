# %%
#standard libraries
import pandas as pd
import numpy as np
import matplotlib.pylab as plt

# %%
#standard libraries
import pandas as pd
import numpy as np
import matplotlib.pylab as plt

# %%
df = pd.read_csv('imputed.csv')
df.head()
# Out:
#          COUNTRY        ID  READING_AVG  MATH_AVG  SCIENCE_AVG   GDP_2018  \
# 0  United States       USA          505       478          502  62605.592
# 1         Russia  USSR-RUS          479       488          478  29266.855
# 2        Belarus  USSR-BLR          474       472          471  20003.029
# 3         Israel       ISR          470       463          462  37972.002
# 4        Ukraine  USSR-UKR          466       453          469   9283.433
#
#    P_Enrollment_Totals  LS_completion  LS_completion_male  \
# 0          24957955.89       98.75227           98.901003
# 1           6927980.00       99.41000           99.630000
# 2            427752.00       99.93871           99.853840
# 3            936214.00       98.07000           99.360000
# 4           1676550.00       99.45947           99.511510
#
#    LS_completion_female  ...  LS_national_assessment  P_annual_exp  \
# 0             98.606098  ...                1.000000  11727.023750
# ...

# %% [markdown]
# # GDP v Output

# %%
plt.scatter(x="GDP_2018", y="SCIENCE_AVG", data = df)

# %%
# more linear as a log
X = np.log(df.GDP_2018)
plt.scatter(x= X, y="SCIENCE_AVG", data = df)

# %% [markdown]
# # Primary Enrollment v Output

# %%
plt.scatter(x="P_Enrollment_Totals", y="SCIENCE_AVG", data = df)

# %%
X = np.log(df.P_Enrollment_Totals)

plt.scatter(x=X, y="SCIENCE_AVG", data = df)

# %% [markdown]
# # LS Completion v Output

# %%
plt.scatter(x="LS_completion", y="SCIENCE_AVG", data = df)

# %%
X = np.log(df.LS_completion_male)

plt.scatter(x=X, y="SCIENCE_AVG", data = df)
# Out:
# C:\Users\diego\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\arraylike.py:358: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %% [markdown]
# # LS Completion (Male) vs Outcome

# %%
plt.scatter(x="LS_completion_male", y="SCIENCE_AVG", data = df)
# Out:
# C:\Users\diego\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\arraylike.py:358: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
X = np.log(df.LS_completion_male)
plt.scatter(x=X, y="SCIENCE_AVG", data = df)
# Out:
# C:\Users\diego\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\arraylike.py:358: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %% [markdown]
# # LS Completion (Female) vs Outcome

# %%
plt.scatter(x="LS_completion_female", y="SCIENCE_AVG", data = df)

# %%
X = np.log(df.LS_completion_female)
plt.scatter(x=X, y="SCIENCE_AVG", data = df)

# %% [markdown]
# # Societal contribution vs Outcome

# %%
plt.scatter(x='teacher_sent_societal_contribution', y="SCIENCE_AVG", data = df)

# %%
#no significant chang with log
X = np.log(df.teacher_sent_societal_contribution)
plt.scatter(x=X, y="SCIENCE_AVG", data = df)

# %% [markdown]
# # Multicultural PD v Outcome

# %% [markdown]
# can't tell tbh

# %%
plt.scatter(x="teacher_need_multicultural_pd", y="SCIENCE_AVG", data = df)

# %%
X = np.log(df.teacher_need_multicultural_pd)
plt.scatter(x=X, y="SCIENCE_AVG", data = df)

# %% [markdown]
# # teacher professional dvlptmt v outcome

# %% [markdown]
# no difference

# %%
plt.scatter(x="teacher_PD_12M_Value", y="SCIENCE_AVG", data = df)

# %%
X = np.log(df.teacher_PD_12M_Value)
plt.scatter(x=X, y="SCIENCE_AVG", data = df)

# %%
df.columns
# Out:
# Index(['COUNTRY', 'ID', 'READING_AVG', 'MATH_AVG', 'SCIENCE_AVG', 'GDP_2018',
#        'P_Enrollment_Totals', 'LS_completion', 'LS_completion_male',
#        'LS_completion_female', 'teacher_sent_societal_contribution',
#        'teacher_need_multicultural_pd', 'teacher_PD_12M_Value',
#        'salary_per_instruction_hr', 'principal_PD_12M_Value', 'LS_ta_presence',
#        'P_ta_presence', 'LS_guard_presence', 'P_sped_ta_presence',
#        'LS_sped_ta_presence', 'P_national_assessment',
#        'LS_national_assessment', 'P_annual_exp', 'LS_annual_exp',
#        'expect_degree', 'test_anxiety', 'study_habits', 'expect_good_grades',
#        'home_comp_internet', 'home_desk_quiet', 'home_schoolbooks'],
#       dtype='object')

# %%
plt.scatter(x="salary_per_instruction_hr", y="SCIENCE_AVG", data = df)

# %%
X = np.log(df.salary_per_instruction_hr)
plt.scatter(x=X, y="SCIENCE_AVG", data = df)

# %% [markdown]
# # Principal PD vs Outcome

# %%
plt.scatter(x="principal_PD_12M_Value", y="SCIENCE_AVG", data = df)

# %%
X = np.log(df.principal_PD_12M_Value)
plt.scatter(x=X, y="SCIENCE_AVG", data = df)

# %% [markdown]
# # Categorical v Outcome

# %%
# i don't think it makes sense to log binary columns
plt.scatter(x="LS_ta_presence", y="SCIENCE_AVG", data = df)

# %% [markdown]
# # P annual exp v Outcome

# %%
plt.scatter(x="P_annual_exp", y="SCIENCE_AVG", data = df)

# %%
X = df.P_annual_exp/df.GDP_2018
plt.scatter(x=X, y="SCIENCE_AVG", data = df)

# %%
X = np.log(df.P_annual_exp/df.GDP_2018)
plt.scatter(x=X, y="SCIENCE_AVG", data = df)

# %% [markdown]
# # L ann exp v outcome

# %%
plt.scatter(x="LS_annual_exp", y="SCIENCE_AVG", data = df)

# %%
X = df.LS_annual_exp/df.GDP_2018
plt.scatter(x=X, y="SCIENCE_AVG", data = df)

# %%
X = np.log(df.LS_annual_exp/df.GDP_2018)
plt.scatter(x=X, y="SCIENCE_AVG", data = df)

# %% [markdown]
# # Degree expectation vs Outcome

# %%
plt.scatter(x="expect_degree", y="SCIENCE_AVG", data = df)

# %%
X = np.log(df.expect_degree)
plt.scatter(x=X, y="SCIENCE_AVG", data = df)

# %% [markdown]
# # Test anxiety v Outcome

# %%
plt.scatter(x="test_anxiety", y="SCIENCE_AVG", data = df)

# %%
X = np.log(df.test_anxiety)
plt.scatter(x=X, y="SCIENCE_AVG", data = df)

# %% [markdown]
# # Study Habits vs Outcomes

# %%
plt.scatter(x="study_habits", y="SCIENCE_AVG", data = df)

# %%
X = np.log(df.study_habits)
plt.scatter(x=X, y="SCIENCE_AVG", data = df)

# %% [markdown]
# # Good Grade Expectation v Outcome

# %%
plt.scatter(x="expect_good_grades", y="SCIENCE_AVG", data = df)

# %%
X = np.log(df.expect_good_grades)
plt.scatter(x=X, y="SCIENCE_AVG", data = df)

# %% [markdown]
# # Computer/Internet at home v Outcome

# %%
plt.scatter(x="home_comp_internet", y="MATH_AVG", data = df)

# %%
X = np.log(df.home_comp_internet)
plt.scatter(x=X, y="MATH_AVG", data = df)

# %% [markdown]
# # Quiet, Study space at Home v Outcome

# %%
plt.scatter(x="home_desk_quiet", y="MATH_AVG", data = df)

# %%
X = np.log(df.home_desk_quiet)
plt.scatter(x=X, y="MATH_AVG", data = df)

# %% [markdown]
# # School Books at Home v Outcome

# %%
plt.scatter(x="home_schoolbooks", y="MATH_AVG", data = df)

# %%
X = np.log(df.home_schoolbooks)
plt.scatter(x=X, y="MATH_AVG", data = df)
