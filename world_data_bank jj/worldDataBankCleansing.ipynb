# %% [markdown]
# # Cleaning Data Notebook for World Data Bank csv

# %% [markdown]
# ### JJ

# %%
import pandas as pd
import numpy as np
import math
import base64

# %%
#Notes will be for me to kind of write down what i'm doing to remind/teach myslef
#Importing Data
df = pd.read_csv('/Users/josejimenez/Downloads/WDI_csv/WDIData.csv')

#I have to find the path in my files and use that

# %%
df.head(10)
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
# 5   Arab World          ARB
# 6   Arab World          ARB
# 7   Arab World          ARB
# 8   Arab World          ARB
# 9   Arab World          ARB
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS   NaN
# 1            Access to electricity (% of population)     EG.ELC.ACCS.ZS   NaN
# 2  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS   NaN
# 3  Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS   NaN
# 4  Account ownership at a financial institution o...     FX.OWN.TOTL.ZS   NaN
# 5  Account ownership at a financial institution o...  FX.OWN.TOTL.FE.ZS   NaN
# 6  Account ownership at a financial institution o...  FX.OWN.TOTL.MA.ZS   NaN
# ...

# %%
df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', 'Unnamed: 65'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Country Name       object
# Country Code       object
# Indicator Name     object
# Indicator Code     object
# 1960              float64
#                    ...
# 2017              float64
# 2018              float64
# 2019              float64
# 2020              float64
# Unnamed: 65       float64
# Length: 66, dtype: object

# %% [markdown]
# I feel like `Country Name` and `Country Code` and `Indicator Name` -but i worry about that column being so fucking long -should both be categories

# %%
df['Country Name'] = df['Country Name'].astype('category')
df['Country Code'] = df['Country Code'].astype('category')

# %%
df.dtypes
# Out:
# Country Name      category
# Country Code      category
# Indicator Name      object
# Indicator Code      object
# 1960               float64
#                     ...
# 2017               float64
# 2018               float64
# 2019               float64
# 2020               float64
# Unnamed: 65        float64
# Length: 66, dtype: object

# %% [markdown]
# Because `Indicator Code` will not be consistent with other data sets i think we should DELETE the shit out of them

# %%
df.drop(columns = ['Indicator Code'], inplace = True)

# %%
df.rename({'Country Name': 'country_id', 'Country Code': 'ID', "Indicator Name": "indicator_name" }, axis=1, inplace = True)

# %%
df.head(25) # I keep not thinking about the inplace this was just to check
# Out:
#     country_id   ID                                     indicator_name  1960  \
# 0   Arab World  ARB  Access to clean fuels and technologies for coo...   NaN
# 1   Arab World  ARB            Access to electricity (% of population)   NaN
# 2   Arab World  ARB  Access to electricity, rural (% of rural popul...   NaN
# 3   Arab World  ARB  Access to electricity, urban (% of urban popul...   NaN
# 4   Arab World  ARB  Account ownership at a financial institution o...   NaN
# 5   Arab World  ARB  Account ownership at a financial institution o...   NaN
# 6   Arab World  ARB  Account ownership at a financial institution o...   NaN
# 7   Arab World  ARB  Account ownership at a financial institution o...   NaN
# 8   Arab World  ARB  Account ownership at a financial institution o...   NaN
# 9   Arab World  ARB  Account ownership at a financial institution o...   NaN
# 10  Arab World  ARB  Account ownership at a financial institution o...   NaN
# ...

# %%
#df['indicator_name'].unique().tolist()

# %% [markdown]
# I'm considering at this point dropping HELLA countries, because not only do i not wanna deal with this many countiries, but should we? I agree with dealing with more than the ones we menetioned as top, but this? This seems excessive, or I'm being la*y. But deciding which ones to delete would have to be a group thing

# %% [markdown]
# Update: we're not gonna drop countries yet. What I am instead going to deal with are all these mf indicators wtf. First thing I will do is make everything lowercase.

# %%
#df['indicator_name'] = df['indicator_name'].str.lower()

# %%
df.head(5)
# Out:
#    country_id   ID                                     indicator_name  1960  \
# 0  Arab World  ARB  Access to clean fuels and technologies for coo...   NaN
# 1  Arab World  ARB            Access to electricity (% of population)   NaN
# 2  Arab World  ARB  Access to electricity, rural (% of rural popul...   NaN
# 3  Arab World  ARB  Access to electricity, urban (% of urban popul...   NaN
# 4  Arab World  ARB  Account ownership at a financial institution o...   NaN
#
#    1961  1962  1963  1964  1965  1966  1967  1968  1969  1970  1971  1972  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# ...

# %% [markdown]
# From what i've looked at on excel it will look like it will be 144 indicators per country/area. but we will remove some because some indicators divide into genders. (Look at last review module for removing) We will also want to change the floats to two decimal points.

# %%
fuckIt = df

# %% [markdown]
# Will be trying a new approach? Also, i'm naming it fuckIt because that was the attitude I had, and it ended up working

# %%
df2 = fuckIt[fuckIt.indicator_name == 'Adjusted net enrollment rate, primary (% of primary school age children)']
#df3 = fuckIt[fuckIt.indicator_name == 'Adjusted net enrollment rate, primary, female (% of primary school age children)']
#df4 = fuckIt[fuckIt.indicator_name == 'Adjusted net enrollment rate, primary, male (% of primary school age children)']
df5 = fuckIt[fuckIt.indicator_name == 'Adjusted savings: education expenditure (% of GNI)']
df6 = fuckIt[fuckIt.indicator_name == 'Adjusted savings: education expenditure (current US$)']
df7 = fuckIt[fuckIt.indicator_name == 'Adolescents out of school (% of lower secondary school age)']
#df8 = fuckIt[fuckIt.indicator_name == 'Adolescents out of school, female (% of female lower secondary school age)']
#df9 = fuckIt[fuckIt.indicator_name == 'Adolescents out of school, male (% of male lower secondary school age)']
#df10 = fuckIt[fuckIt.indicator_name == 'Average working hours of children, study and work, ages 7-14 (hours per week)']
#df11 = fuckIt[fuckIt.indicator_name == 'Average working hours of children, study and work, female, ages 7-14 (hours per week)']
#df12 = fuckIt[fuckIt.indicator_name == 'Average working hours of children, study and work, male, ages 7-14 (hours per week)']
df13 = fuckIt[fuckIt.indicator_name == 'Children out of school (% of primary school age)']
#df14 = fuckIt[fuckIt.indicator_name == 'Children out of school, female (% of female primary school age)']
#df15 = fuckIt[fuckIt.indicator_name == 'Children out of school, male (% of male primary school age)']
df16 = fuckIt[fuckIt.indicator_name == 'Children out of school, primary']
#df17 = fuckIt[fuckIt.indicator_name == 'Children out of school, primary, female']
#df18 = fuckIt[fuckIt.indicator_name == 'Children out of school, primary, male']
df19 = fuckIt[fuckIt.indicator_name == 'Compulsory education, duration (years)']
df20 = fuckIt[fuckIt.indicator_name == 'Current education expenditure, primary (% of total expenditure in primary public institutions)']
df21 = fuckIt[fuckIt.indicator_name == 'Current education expenditure, secondary (% of total expenditure in secondary public institutions)']
df22 = fuckIt[fuckIt.indicator_name == 'Current education expenditure, tertiary (% of total expenditure in tertiary public institutions)']
df23 = fuckIt[fuckIt.indicator_name == 'Current education expenditure, total (% of total expenditure in public institutions)']
#df24 = fuckIt[fuckIt.indicator_name == "Educational attainment, at least Bachelor's or equivalent, population 25+, female (%) (cumulative)"]
#df25 = fuckIt[fuckIt.indicator_name == "Educational attainment, at least Bachelor's or equivalent, population 25+, male (%) (cumulative)"]
#df26 = fuckIt[fuckIt.indicator_name == "Educational attainment, at least Bachelor's or equivalent, population 25+, total (%) (cumulative)"]
df27 = fuckIt[fuckIt.indicator_name == 'Educational attainment, at least completed lower secondary, population 25+, female (%) (cumulative)']
df28 = fuckIt[fuckIt.indicator_name == 'Educational attainment, at least completed lower secondary, population 25+, male (%) (cumulative)']
df29 = fuckIt[fuckIt.indicator_name == 'Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)']
df30 = fuckIt[fuckIt.indicator_name == 'Educational attainment, at least completed post-secondary, population 25+, female (%) (cumulative)']
df31 = fuckIt[fuckIt.indicator_name == 'Educational attainment, at least completed post-secondary, population 25+, male (%) (cumulative)']
df32 = fuckIt[fuckIt.indicator_name == 'Educational attainment, at least completed post-secondary, population 25+, total (%) (cumulative)']
df33 = fuckIt[fuckIt.indicator_name == 'Educational attainment, at least completed primary, population 25+ years, female (%) (cumulative)']
df34 = fuckIt[fuckIt.indicator_name == 'Educational attainment, at least completed primary, population 25+ years, male (%) (cumulative)']
df35 = fuckIt[fuckIt.indicator_name == 'Educational attainment, at least completed primary, population 25+ years, total (%) (cumulative)']
#df36 = fuckIt[fuckIt.indicator_name == 'Educational attainment, at least completed short-cycle tertiary, population 25+, female (%) (cumulative)']
#df37 = fuckIt[fuckIt.indicator_name == 'Educational attainment, at least completed short-cycle tertiary, population 25+, male (%) (cumulative)']
#df38 = fuckIt[fuckIt.indicator_name == 'Educational attainment, at least completed short-cycle tertiary, population 25+, total (%) (cumulative)']
df39 = fuckIt[fuckIt.indicator_name == 'Educational attainment, at least completed upper secondary, population 25+, female (%) (cumulative)']
df40 = fuckIt[fuckIt.indicator_name == 'Educational attainment, at least completed upper secondary, population 25+, male (%) (cumulative)']
df41 = fuckIt[fuckIt.indicator_name == 'Educational attainment, at least completed upper secondary, population 25+, total (%) (cumulative)']
#df42 = fuckIt[fuckIt.indicator_name == "Educational attainment, at least Master's or equivalent, population 25+, female (%) (cumulative)"]
#df43 = fuckIt[fuckIt.indicator_name == "Educational attainment, at least Master's or equivalent, population 25+, male (%) (cumulative)"]
#df44 = fuckIt[fuckIt.indicator_name == "Educational attainment, at least Master's or equivalent, population 25+, total (%) (cumulative)"]
#df45 = fuckIt[fuckIt.indicator_name == 'Educational attainment, Doctoral or equivalent, population 25+, female (%) (cumulative)']
#df46 = fuckIt[fuckIt.indicator_name == 'Educational attainment, Doctoral or equivalent, population 25+, male (%) (cumulative)']
#df47 = fuckIt[fuckIt.indicator_name == 'Educational attainment, Doctoral or equivalent, population 25+, total (%) (cumulative)']
df48 = fuckIt[fuckIt.indicator_name == 'Expenditure on primary education (% of government expenditure on education)']
df49 = fuckIt[fuckIt.indicator_name == 'Expenditure on secondary education (% of government expenditure on education)']
#df50 = fuckIt[fuckIt.indicator_name == 'Expenditure on tertiary education (% of government expenditure on education)']
df51 = fuckIt[fuckIt.indicator_name == 'GDP growth (annual %)']
df52 = fuckIt[fuckIt.indicator_name == 'Government expenditure on education, total (% of GDP)']
df53 = fuckIt[fuckIt.indicator_name == 'Government expenditure on education, total (% of government expenditure)']
df54 = fuckIt[fuckIt.indicator_name == 'Government expenditure per student, primary (% of GDP per capita)']
df55 = fuckIt[fuckIt.indicator_name == 'Government expenditure per student, secondary (% of GDP per capita)']
#df56 = fuckIt[fuckIt.indicator_name == 'Government expenditure per student, tertiary (% of GDP per capita)']
#df57 = fuckIt[fuckIt.indicator_name == 'Gross intake ratio in first grade of primary education, female (% of relevant age group)']
#df58 = fuckIt[fuckIt.indicator_name == 'Gross intake ratio in first grade of primary education, male (% of relevant age group)']
df59 = fuckIt[fuckIt.indicator_name == 'Gross intake ratio in first grade of primary education, total (% of relevant age group)']
#df60 = fuckIt[fuckIt.indicator_name == 'Individuals using the Internet (% of population)']
#df61 = fuckIt[fuckIt.indicator_name == 'Literacy rate, adult female (% of females ages 15 and above)']
#df62 = fuckIt[fuckIt.indicator_name == 'Literacy rate, adult male (% of males ages 15 and above)']
#df63 = fuckIt[fuckIt.indicator_name == 'Literacy rate, adult total (% of people ages 15 and above)']
#df64 = fuckIt[fuckIt.indicator_name == 'Literacy rate, youth (ages 15-24), gender parity index (GPI)']
#df65 = fuckIt[fuckIt.indicator_name == 'Literacy rate, youth female (% of females ages 15-24)']
#df66 = fuckIt[fuckIt.indicator_name == 'Literacy rate, youth male (% of males ages 15-24)']
df67 = fuckIt[fuckIt.indicator_name == 'Literacy rate, youth total (% of people ages 15-24)']
#df68 = fuckIt[fuckIt.indicator_name == 'Net intake rate in grade 1 (% of official school-age population)']
#df69 = fuckIt[fuckIt.indicator_name == 'Net intake rate in grade 1, female (% of official school-age population)']
#df70 = fuckIt[fuckIt.indicator_name == 'Net intake rate in grade 1, male (% of official school-age population)']
#df71 = fuckIt[fuckIt.indicator_name == 'Over-age students, primary (% of enrollment)']
#df72 = fuckIt[fuckIt.indicator_name == 'Over-age students, primary, female (% of female enrollment)']
#df73 = fuckIt[fuckIt.indicator_name == 'Over-age students, primary, male (% of male enrollment)']
#df74 = fuckIt[fuckIt.indicator_name == 'Population ages 0-14 (% of total population)']
#df75 = fuckIt[fuckIt.indicator_name == 'Population ages 0-14, female (% of female population)']
#df76 = fuckIt[fuckIt.indicator_name == 'Population ages 0-14, male (% of male population)']
#df77 = fuckIt[fuckIt.indicator_name == 'Population ages 0-14, total']
#df78 = fuckIt[fuckIt.indicator_name == 'Population ages 15-19, female (% of female population)']
#df79 = fuckIt[fuckIt.indicator_name == 'Population ages 15-19, male (% of male population)']
df80 = fuckIt[fuckIt.indicator_name == 'Preprimary education, duration (years)']
#df81 = fuckIt[fuckIt.indicator_name == 'Primary completion rate, female (% of relevant age group)']
#df82 = fuckIt[fuckIt.indicator_name == 'Primary completion rate, male (% of relevant age group)']
df83 = fuckIt[fuckIt.indicator_name == 'Primary completion rate, total (% of relevant age group)']
df84 = fuckIt[fuckIt.indicator_name == 'Primary education, duration (years)']
df85 = fuckIt[fuckIt.indicator_name == 'Primary education, pupils']
df86 = fuckIt[fuckIt.indicator_name == 'Primary education, pupils (% female)']
df87 = fuckIt[fuckIt.indicator_name == 'Primary education, teachers']
df88 = fuckIt[fuckIt.indicator_name == 'Primary education, teachers (% female)']
df89 = fuckIt[fuckIt.indicator_name == 'Primary school starting age (years)']
df90 = fuckIt[fuckIt.indicator_name == 'Pupil-teacher ratio, lower secondary']
df91 = fuckIt[fuckIt.indicator_name == 'Pupil-teacher ratio, preprimary']
df92 = fuckIt[fuckIt.indicator_name == 'Pupil-teacher ratio, primary']
df93 = fuckIt[fuckIt.indicator_name == 'Pupil-teacher ratio, secondary']
#df94 = fuckIt[fuckIt.indicator_name == 'Pupil-teacher ratio, tertiary']
df95 = fuckIt[fuckIt.indicator_name == 'Pupil-teacher ratio, upper secondary']
df96 = fuckIt[fuckIt.indicator_name == 'School enrollment, preprimary (% gross)']
#df97 = fuckIt[fuckIt.indicator_name == 'School enrollment, preprimary, female (% gross)']
#df98 = fuckIt[fuckIt.indicator_name == 'School enrollment, preprimary, male (% gross)']
df99 = fuckIt[fuckIt.indicator_name == 'School enrollment, primary (% gross)']
#df100 = fuckIt[fuckIt.indicator_name == 'School enrollment, primary (% net)']
df101 = fuckIt[fuckIt.indicator_name == 'School enrollment, primary (gross), gender parity index (GPI)']
df102 = fuckIt[fuckIt.indicator_name == 'School enrollment, primary and secondary (gross), gender parity index (GPI)']
#df103 = fuckIt[fuckIt.indicator_name == 'School enrollment, primary, female (% gross)']
#df104 = fuckIt[fuckIt.indicator_name == 'School enrollment, primary, female (% net)']
#df105 = fuckIt[fuckIt.indicator_name == 'School enrollment, primary, male (% gross)']
#df106 = fuckIt[fuckIt.indicator_name == 'School enrollment, primary, male (% net)']
#df107 = fuckIt[fuckIt.indicator_name == 'School enrollment, primary, private (% of total primary)']
df108 = fuckIt[fuckIt.indicator_name == 'School enrollment, secondary (% gross)']
#df109 = fuckIt[fuckIt.indicator_name == 'School enrollment, secondary (% net)']
df110 = fuckIt[fuckIt.indicator_name == 'School enrollment, secondary (gross), gender parity index (GPI)']
#df111 = fuckIt[fuckIt.indicator_name == 'School enrollment, secondary, female (% gross)']
#df112 = fuckIt[fuckIt.indicator_name == 'School enrollment, secondary, female (% net)']
#df113 = fuckIt[fuckIt.indicator_name == 'School enrollment, secondary, male (% gross)']
#df114 = fuckIt[fuckIt.indicator_name == 'School enrollment, secondary, male (% net)']
#df115 = fuckIt[fuckIt.indicator_name == 'School enrollment, secondary, private (% of total secondary)']
#df116 = fuckIt[fuckIt.indicator_name == 'School enrollment, tertiary (% gross)']
#df117 = fuckIt[fuckIt.indicator_name == 'School enrollment, tertiary (gross), gender parity index (GPI)']
#df118 = fuckIt[fuckIt.indicator_name == 'School enrollment, tertiary, female (% gross)']
#df119 = fuckIt[fuckIt.indicator_name == 'School enrollment, tertiary, male (% gross)']
df120 = fuckIt[fuckIt.indicator_name == 'Secondary education, duration (years)']
#df121 = fuckIt[fuckIt.indicator_name == 'Secondary education, general pupils']
#df122 = fuckIt[fuckIt.indicator_name == 'Secondary education, general pupils (% female)']
#df123 = fuckIt[fuckIt.indicator_name == 'Secondary education, pupils']
#df124 = fuckIt[fuckIt.indicator_name == 'Secondary education, pupils (% female)']
#df125 = fuckIt[fuckIt.indicator_name == 'Secondary education, teachers']
#df126 = fuckIt[fuckIt.indicator_name == 'Secondary education, teachers (% female)']
#df127 = fuckIt[fuckIt.indicator_name == 'Secondary education, teachers, female']
#df128 = fuckIt[fuckIt.indicator_name == 'Secondary education, vocational pupils']
#df129 = fuckIt[fuckIt.indicator_name == 'Secondary education, vocational pupils (% female)']
#df130 = fuckIt[fuckIt.indicator_name == 'Tertiary education, academic staff (% female)']
df131 = fuckIt[fuckIt.indicator_name == 'Trained teachers in lower secondary education (% of total teachers)']
#df132 = fuckIt[fuckIt.indicator_name == 'Trained teachers in lower secondary education, female (% of female teachers)']
#df133 = fuckIt[fuckIt.indicator_name == 'Trained teachers in lower secondary education, male (% of male teachers)']
df134 = fuckIt[fuckIt.indicator_name == 'Trained teachers in preprimary education (% of total teachers)']
#df135 = fuckIt[fuckIt.indicator_name == 'Trained teachers in preprimary education, female (% of female teachers)']
#df136 = fuckIt[fuckIt.indicator_name == 'Trained teachers in preprimary education, male (% of male teachers)']
df137 = fuckIt[fuckIt.indicator_name == 'Trained teachers in primary education (% of total teachers)']
#df138 = fuckIt[fuckIt.indicator_name == 'Trained teachers in primary education, female (% of female teachers)']
#df139 = fuckIt[fuckIt.indicator_name == 'Trained teachers in primary education, male (% of male teachers)']
df140 = fuckIt[fuckIt.indicator_name == 'Trained teachers in secondary education (% of total teachers)']
#df141 = fuckIt[fuckIt.indicator_name == 'Trained teachers in secondary education, female (% of female teachers)']
#df142 = fuckIt[fuckIt.indicator_name == 'Trained teachers in secondary education, male (% of male teachers)']
df143 = fuckIt[fuckIt.indicator_name == 'Trained teachers in upper secondary education (% of total teachers)']
#df144 = fuckIt[fuckIt.indicator_name == 'Trained teachers in upper secondary education, female (% of female teachers)']
#df145 = fuckIt[fuckIt.indicator_name == 'Trained teachers in upper secondary education, male (% of male teachers)']

# %%
world_data_drivers = df2.append([df5,df6,df7,df13,df16,df19,df20,
    df21,df22,df23,df27,df28,df29,df30,df31,df32,df33,df34,df35,
    df39,df40,df41,df48,df49,df51,df52,df53,df54,df55,df59,df67,
    df80,df83,df84,df85,df86,df87,df88,df89,df90,df91,df92,df93,
    df95,df96,df99,df101,df102,df108,df110,df120,df131,df134,
    df137,df140,df143])

# %%
world_data_drivers.head(120)
# Out:
#                             country_id   ID  \
# 17                          Arab World  ARB
# 1460            Caribbean small states  CSS
# 2903    Central Europe and the Baltics  CEB
# 4346        Early-demographic dividend  EAR
# 5789               East Asia & Pacific  EAS
# ...                                ...  ...
# 165962                          France  FRA
# 167405                French Polynesia  PYF
# 168848                           Gabon  GAB
# 170291                     Gambia, The  GMB
# 171734                         Georgia  GEO
#
#                                            indicator_name  1960  1961  1962  \
# 17      Adjusted net enrollment rate, primary (% of pr...   NaN   NaN   NaN
# 1460    Adjusted net enrollment rate, primary (% of pr...   NaN   NaN   NaN
# 2903    Adjusted net enrollment rate, primary (% of pr...   NaN   NaN   NaN
# 4346    Adjusted net enrollment rate, primary (% of pr...   NaN   NaN   NaN
# ...

# %%
world_data_drivers['indicator_name'] = world_data_drivers['indicator_name'].str.lower()

# %%
world_data_drivers.head(5)
# Out:
#                           country_id   ID  \
# 17                        Arab World  ARB
# 1460          Caribbean small states  CSS
# 2903  Central Europe and the Baltics  CEB
# 4346      Early-demographic dividend  EAR
# 5789             East Asia & Pacific  EAS
#
#                                          indicator_name  1960  1961  1962  \
# 17    adjusted net enrollment rate, primary (% of pr...   NaN   NaN   NaN
# 1460  adjusted net enrollment rate, primary (% of pr...   NaN   NaN   NaN
# 2903  adjusted net enrollment rate, primary (% of pr...   NaN   NaN   NaN
# 4346  adjusted net enrollment rate, primary (% of pr...   NaN   NaN   NaN
# 5789  adjusted net enrollment rate, primary (% of pr...   NaN   NaN   NaN
#
#       1963  1964  1965  1966  1967  1968  1969  1970  1971  1972  1973  1974  \
# 17     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1460   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...

# %%
world_data_drivers.shape
# Out:
# (15048, 65)

# %%
world_data_drivers.round(decimals= 2)
# Out:
#                             country_id   ID  \
# 17                          Arab World  ARB
# 1460            Caribbean small states  CSS
# 2903    Central Europe and the Baltics  CEB
# 4346        Early-demographic dividend  EAR
# 5789               East Asia & Pacific  EAS
# ...                                ...  ...
# 375111           Virgin Islands (U.S.)  VIR
# 376554              West Bank and Gaza  PSE
# 377997                     Yemen, Rep.  YEM
# 379440                          Zambia  ZMB
# 380883                        Zimbabwe  ZWE
#
#                                            indicator_name  1960  1961  1962  \
# 17      adjusted net enrollment rate, primary (% of pr...   NaN   NaN   NaN
# 1460    adjusted net enrollment rate, primary (% of pr...   NaN   NaN   NaN
# 2903    adjusted net enrollment rate, primary (% of pr...   NaN   NaN   NaN
# 4346    adjusted net enrollment rate, primary (% of pr...   NaN   NaN   NaN
# ...

# %%
world_data_drivers.dtypes
# Out:
# country_id        category
# ID                category
# indicator_name      object
# 1960               float64
# 1961               float64
#                     ...
# 2017               float64
# 2018               float64
# 2019               float64
# 2020               float64
# Unnamed: 65        float64
# Length: 65, dtype: object

# %%
for i in world_data_drivers:
    print(world_data_drivers[i].isnull().sum())

# %% [markdown]
# Because of the above finding, I feel instead as though I should eliminate rows on my own, or maybe I should just make sure there are countries instead of regions.

# %%
world_data_drivers['country_id'].unique().tolist()

# %%
get_rid_country = ["Arab World", "Caribbean small states", "Central Europe and the Baltics", "Early-demographic dividend", "East Asia & Pacific",
    "East Asia & Pacific (excluding high income)", "East Asia & Pacific (IDA & IBRD countries)", "Euro area", "Europe & Central Asia",
     "Europe & Central Asia (excluding high income)","Europe & Central Asia (IDA & IBRD countries)", "European Union", "Fragile and conflict affected situations",
      "Heavily indebted poor countries (HIPC)", "High income", "IBRD only", "IDA & IBRD total", "IDA blend", "IDA only", "IDA total", "Late-demographic dividend",
       "Latin America & Caribbean", "Latin America & Caribbean (excluding high income)", "Latin America & the Caribbean (IDA & IBRD countries)",
        "Least developed countries: UN classification", "Low & middle income", "Low income", "Lower middle income", "Middle East & North Africa",
         "Middle East & North Africa (excluding high income)", "Middle East & North Africa (IDA & IBRD countries)", "Middle income", "North America",
          "Not classified", "OECD members", "Other small states", "Pacific island small states", "Post-demographic dividend", "Pre-demographic dividend",
           "Small states", "South Asia", "South Asia (IDA & IBRD)", "Sub-Saharan Africa", "Sub-Saharan Africa (excluding high income)",
            "Sub-Saharan Africa (IDA & IBRD countries)", "Upper middle income", "World"]

# %%
test_elim = world_data_drivers #creating a new data set to test get ridding of all these sub-cats of countries

# %%
test_elim = test_elim[~test_elim['country_id'].isin(get_rid_country)]

# %%
test_elim.shape
# Out:
# (12369, 65)

# %%
test_elim.head(10)
# Out:
#                 country_id   ID  \
# 67838          Afghanistan  AFG
# 69281              Albania  ALB
# 70724              Algeria  DZA
# 72167       American Samoa  ASM
# 73610              Andorra  AND
# 75053               Angola  AGO
# 76496  Antigua and Barbuda  ATG
# 77939            Argentina  ARG
# 79382              Armenia  ARM
# 80825                Aruba  ABW
#
#                                           indicator_name  1960  1961  1962  \
# 67838  adjusted net enrollment rate, primary (% of pr...   NaN   NaN   NaN
# 69281  adjusted net enrollment rate, primary (% of pr...   NaN   NaN   NaN
# 70724  adjusted net enrollment rate, primary (% of pr...   NaN   NaN   NaN
# 72167  adjusted net enrollment rate, primary (% of pr...   NaN   NaN   NaN
# 73610  adjusted net enrollment rate, primary (% of pr...   NaN   NaN   NaN
# 75053  adjusted net enrollment rate, primary (% of pr...   NaN   NaN   NaN
# 76496  adjusted net enrollment rate, primary (% of pr...   NaN   NaN   NaN
# ...

# %%
for i in test_elim:
    print(test_elim[i].isnull().sum())

# %% [markdown]
# I think it might be that there a lot of countries that do not participate in providing the data maybe. Will see once we save this shit.

# %%
world_data_final = test_elim.round(decimals= 2)

# %%
world_data_final = world_data_final.reset_index(drop = True)

# %%
world_data_final
# Out:
#                   country_id   ID  \
# 0                Afghanistan  AFG
# 1                    Albania  ALB
# 2                    Algeria  DZA
# 3             American Samoa  ASM
# 4                    Andorra  AND
# ...                      ...  ...
# 12364  Virgin Islands (U.S.)  VIR
# 12365     West Bank and Gaza  PSE
# 12366            Yemen, Rep.  YEM
# 12367                 Zambia  ZMB
# 12368               Zimbabwe  ZWE
#
#                                           indicator_name  1960  1961  1962  \
# 0      adjusted net enrollment rate, primary (% of pr...   NaN   NaN   NaN
# 1      adjusted net enrollment rate, primary (% of pr...   NaN   NaN   NaN
# 2      adjusted net enrollment rate, primary (% of pr...   NaN   NaN   NaN
# 3      adjusted net enrollment rate, primary (% of pr...   NaN   NaN   NaN
# 4      adjusted net enrollment rate, primary (% of pr...   NaN   NaN   NaN
# ...                                                  ...   ...   ...   ...
# ...

# %%
world_data_final = world_data_final.drop(columns=['Unnamed: 65']) #2020 you're next

# %%
world_data_final.shape

# %% [markdown]
# After looking at the data in an excel sheet, I see that we don't really need the years 1960-1969. The only available data for those columns are the indicators pertaining to the population at that time, which are not going to be strong indicators in my opinion.

# %%
years_to_get_rid = ['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967',
    '1968', '1969','1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
    '1978', '1979','1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987',
    '1988', '1989','1990', '1991', '1992', '1993', '1994']

# %%
#world_data_final = world_data_final.drop(columns = ['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969']) ##2020 you're still next

world_data_final = world_data_final.drop( columns = years_to_get_rid)

# %%
pd.options.display.max_columns = 100
world_data_final.head(5)
# Out:
#        country_id   ID                                     indicator_name  \
# 0     Afghanistan  AFG  adjusted net enrollment rate, primary (% of pr...
# 1         Albania  ALB  adjusted net enrollment rate, primary (% of pr...
# 2         Algeria  DZA  adjusted net enrollment rate, primary (% of pr...
# 3  American Samoa  ASM  adjusted net enrollment rate, primary (% of pr...
# 4         Andorra  AND  adjusted net enrollment rate, primary (% of pr...
#
#     1995   1996   1997  1998   1999   2000   2001  2002   2003   2004  2005  \
# 0    NaN    NaN    NaN   NaN    NaN    NaN    NaN   NaN    NaN    NaN   NaN
# 1    NaN    NaN    NaN   NaN  96.79  95.38  93.87   NaN  91.70  90.92   NaN
# 2  88.39  87.92  87.36   NaN  90.05  90.75  92.75  93.9  94.36  95.08  95.4
# 3    NaN    NaN    NaN   NaN    NaN    NaN    NaN   NaN    NaN    NaN   NaN
# 4    NaN    NaN    NaN   NaN    NaN    NaN    NaN   NaN    NaN    NaN   NaN
#
# ...

# %%
list_of_countries = [world_data_final['country_id'].unique()]

# %% [markdown]
# What I can do is create a multi-index dataframe and then find the missing values by each country there? Since there will only be one element in `country_name` of the country.

# %% [markdown]
# Trying to make an argument to deleting  a bunch of countries too. Many countries do not measure PISA scores, so I feel like what is the need to have them here, if thye do not have data for what we want. I am using a different data set, from the world data bank for this to determine which countries do not have PISA data.

# %%
countries_no_pisa = ['Afghanistan', 'Algeria', 'American Samoa', 'Andorra', 'Angola', 'Antigua and Barbuda', 'Armenia', 'Aruba', 'Bahamas, The',
     'Bahrain', 'Bangladesh', 'Barbados', 'Belarus', 'Belize', 'Benin', 'Bermuda', 'Bhutan', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 
     'British Virgin Islands', 'Brunei Darussalam', 'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia', 'Cameroon', 'Cayman Islands', 'Chad',
     'Channel Islands', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.', "Cote d'Ivoire", 'Cuba', 'Curacao', 'Djibouti', 'Dominica', 'Ecuador',
     'Egypt, Arab Rep.', 'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Eswatini', 'Ethiopia', 'Faroe Islands', 'Fiji', 'French Polynesia',
     'Gabon', 'Gambia, The', 'Ghana', 'Gibraltar', 'Greenland', 'Grenada', 'Guam', 'Guatemala', 'Guinea', 'Guinea-Bissau', 'Guyana', 'Haiti',
     'Honduras', 'India', 'Iran, Islamic Rep.', 'Iraq', 'Isle of Man', 'Jamaica', 'Kenya', 'Kiribati', 'Korea, Dem. People’s Rep.', 'Kuwait',
     'Lao PDR', 'Lesotho', 'Liberia', 'Libya', 'Madagascar', 'Malawi', 'Maldives', 'Mali', 'Marshall Islands', 'Mauritania', 'Mauritius', 
     'Mayotte', 'Micronesia, Fed. Sts.', 'Moldova', 'Monaco', 'Mongolia', 'Morocco', 'Mozambique', 'Myanmar', 'Namibia', 'Nauru', 'Nepal',
     'Netherlands Antilles', 'New Caledonia', 'Nicaragua', 'Niger', 'Nigeria', 'Northern Mariana Islands', 'Oman', 'Pakistan', 'Palau', 'Papua New Guinea', 
     'Paraguay', 'Philippines', 'Puerto Rico', 'Rwanda', 'Samoa', 'San Marino', 'Sao Tome and Principe', 'Saudi Arabia', 'Senegal', 'Seychelles',
     'Sierra Leone', 'Sint Maarten (Dutch part)', 'Solomon Islands', 'Somalia', 'South Africa', 'South Sudan', 'Sri Lanka', 'St. Kitts and Nevis', 
     'St. Lucia', 'St. Martin (French part)', 'St. Vincent and the Grenadines', 'Sudan', 'Suriname', 'Syrian Arab Republic', 'Tajikistan', 'Tanzania',
     'Timor-Leste', 'Togo', 'Tokelau', 'Tonga', 'Turkmenistan', 'Turks and Caicos Islands', 'Tuvalu', 'Uganda', 'Ukraine', 'Uzbekistan', 'Vanuatu',
     'Venezuela, RB', 'Virgin Islands (U.S.)', 'West Bank and Gaza', 'Yemen, Rep.', 'Zambia', 'Zimbabwe']

# %%
test_elim2 = world_data_final

# %%
test_elim2 = test_elim2[~test_elim2['country_id'].isin(countries_no_pisa)]

# %%
test_elim2.head(50)

# %%
for i in test_elim2:
    print(test_elim2[i].isnull().sum())

# %% [markdown]
# That's honestly a lot better in my opinion, if someone thinks otherwise, it's on sight.

# %%
final_code = test_elim2

# %%
final_code.head(15)
# Out:
#                   country_id   ID  \
# 1                    Albania  ALB
# 7                  Argentina  ARG
# 10                 Australia  AUS
# 11                   Austria  AUT
# 12                Azerbaijan  AZE
# 18                   Belgium  BEL
# 26                    Brazil  BRA
# 29                  Bulgaria  BGR
# 35                    Canada  CAN
# 37  Central African Republic  CAF
# 40                     Chile  CHL
# 41                     China  CHN
# 42                  Colombia  COL
# 46                Costa Rica  CRI
# 48                   Croatia  HRV
#
#                                        indicator_name   1995   1996    1997  \
# 1   adjusted net enrollment rate, primary (% of pr...    NaN    NaN     NaN
# 7   adjusted net enrollment rate, primary (% of pr...    NaN    NaN  100.00
# 10  adjusted net enrollment rate, primary (% of pr...  95.00  95.40   94.98
# 11  adjusted net enrollment rate, primary (% of pr...    NaN    NaN     NaN
# ...

# %%
 ###Creating a multi index dataframe using country as the main main.
maybe_better = final_code.pivot_table(index = ['country_id','country_code','indicator_name'])

# %%
maybe_better.head(5)

# %%
final_code.to_csv("/Users/josejimenez/Downloads/world_data_bank_clean2.csv", encoding = "utf-8", index = False)
